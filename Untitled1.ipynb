# %%
import requests, json
a=requests.get("https://openapi.twse.com.tw/v1/opendata/t187ap11_L")
d=json.loads(a.text)
print(d[1])
for a in d:
    print(a['公司名稱'])
# Out:
# {'出表日期': '1110620', '資料年月': '11105', '公司代號': '1101', '公司名稱': '台泥', '職稱': '董事長之法人代表人', '姓名': '張安平', '選任時持股 ': '0', '目前持股': '2188553', '設質股數': '0', '設質股數佔持股比例': '0.00%', '內部人關係人目前持股合計': '4181917', '內部人關係人設質股數': '0', '內部人關係人設質比例': '0.00%'}
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 台泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 亞泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 嘉泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 環泥
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# 幸福
# ...
